# %%
pip uninstall opencv-python-headless==4.5.5.62
# Out:
# WARNING: Skipping opencv-python-headless as it is not installed.

# %%
pip install opencv-python-headless==4.5.2.52
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 38.2 MB 1.1 MB/s
# ...

# %%
 pip install https://github.com/drivendataorg/zamba/releases/latest/download/zamba.tar.gz
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 40.7 MB 1.2 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#   Cloning https://github.com/r-b-g-b/YOLOX.git (to revision build-requirements) to /tmp/pip-install-cy0c6odn/yolox_66173c3b9804470eb5efc1350a8e6aec
#   Running command git clone -q https://github.com/r-b-g-b/YOLOX.git /tmp/pip-install-cy0c6odn/yolox_66173c3b9804470eb5efc1350a8e6aec
#   Running command git checkout -b build-requirements --track origin/build-requirements
#   Switched to a new branch 'build-requirements'
#   Branch 'build-requirements' set up to track remote branch 'build-requirements' from 'origin'.
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...

# %%
 pip show zamba
# Out:
# Name: zamba
# Version: 2.1.0
# Summary: Zamba is a command line tool and Python package to identify animals in camera trap videos and train custom models for new species and habitats.
# Home-page: https://github.com/drivendataorg/zamba
# Author: DrivenData
# Author-email: info@drivendata.org
# License: UNKNOWN
# Location: /usr/local/lib/python3.7/dist-packages
# Requires: numpy, opencv-python-headless, pandas-path, thop, torch, torchinfo, importlib-metadata, gitpython, pydantic, pandas, pytorchvideo, fvcore, cloudpathlib, timm, future, torchvision, tensorboard, openpyxl, pytorch-lightning, ffmpeg-python, tqdm, av, loguru, appdirs, python-dotenv, scikit-learn, yolox, typer
# Required-by:

# %%
from zamba.models.model_manager import predict_model
from zamba.models.config import PredictConfig

predict_config = PredictConfig(data_dir="/content/")
predict_model(predict_config=predict_config)
# Out:
# 2022-07-31 08:23:33.754 | INFO     | zamba.models.config:get_filepaths:699 - Getting files in /content.
# 2022-07-31 08:24:01.230 | WARNING  | zamba.models.config:get_filepaths:714 - Ignoring 21222 file(s) with suffixes {'', '.ppt', '.pdf', '.pptx', '.docx', '.t7', '.json', '.csv', '.ipynb', '.png', '.xlsx', '.gslides', '.zip', '.jpg', '.h5', '.gsite', '.caffemodel', '.md', '.ova', '.rar', '.gdoc', '.exe', '.txt', '.gform', '.log', '.gsheet', '.yaml', '.mov'}. To include, specify all video suffixes with a VIDEO_SUFFIXES environment variable.
# 2022-07-31 08:24:01.233 | INFO     | zamba.models.config:get_filepaths:720 - Found 12 videos in /content.
# 2022-07-31 08:24:01.285 | INFO     | zamba.models.config:check_files_exist_and_load:105 - Checking all 12 filepaths exist. Can take up to a minute for every couple thousand files.
# ...
